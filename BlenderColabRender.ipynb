# %% [markdown]
# <a href="https://colab.research.google.com/github/keirace/cn409/blob/master/BlenderColabRender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Dec 27 06:18:18 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
#Download Blender from Repository
# !wget https://download.blender.org/release/Blender2.91/blender-2.91.0-linux64.tar.xz
# Out:
# --2020-12-27 06:18:22--  https://download.blender.org/release/Blender2.91/blender-2.91.0-linux64.tar.xz
# Resolving download.blender.org (download.blender.org)... 82.94.213.221
# Connecting to download.blender.org (download.blender.org)|82.94.213.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151566984 (145M) [application/octet-stream]
# Saving to: ‘blender-2.91.0-linux64.tar.xz’
#
# blender-2.91.0-linu 100%[===================>] 144.54M  3.80MB/s    in 46s
#
# 2020-12-27 06:19:08 (3.13 MB/s) - ‘blender-2.91.0-linux64.tar.xz’ saved [151566984/151566984]

# %%
#Install Blender 
# !tar xf blender-2.91.0-linux64.tar.xz

# %%
#Download some required libraries
# !apt install libboost-all-dev
# !apt install libgl1-mesa-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1-mesa-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libgl1-mesa-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
filename = '/content/drive/MyDrive/render/forest_new.blend'

# %%
#Run Blender
#animation -s start -e end
# !sudo ./blender-2.91.0-linux64/blender -b $filename -noaudio -P '/content/drive/MyDrive/render/GPU.py'  -E 'CYCLES' -s 1 -e 160 -a
#frame
#!sudo ./blender-2.91.0-linux64/blender -b $filename -noaudio -- --cycles-device CUDA  -E 'CYCLES' -f 1 -F 'PNG'
# Out:
# Blender 2.91.0 (hash 0f45cab862b8 built 2020-11-25 08:51:08)
# found bundled python: /content/blender-2.91.0-linux64/2.91/python
# Read blend: /content/drive/MyDrive/render/forest_new.blend
# Fra:1 Mem:326.48M (Peak 402.97M) | Time:00:01.30 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Cube
# Fra:1 Mem:327.59M (Peak 402.97M) | Time:00:01.31 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Tree Branch
# Fra:1 Mem:327.70M (Peak 402.97M) | Time:00:01.31 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Landscape.002
# Fra:1 Mem:479.16M (Peak 479.32M) | Time:00:05.57 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Fog
# Fra:1 Mem:479.24M (Peak 479.32M) | Time:00:05.57 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Synchronizing object | Plane
# Fra:1 Mem:479.16M (Peak 479.32M) | Time:00:05.57 | Mem:0.00M, Peak:0.00M | Scene, View Layer | Initializing
# ...

# %%
pwd
# Out:
# '/content'
